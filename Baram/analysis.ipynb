# %%
import pandas as pd

# %%
df = pd.read_csv('./data/baram_ranker.csv')
ocid = pd.read_csv('./data/ocid.csv')
basic = pd.read_csv('./data/basic.csv')
stat_df = pd.read_csv('./data/stat_df.csv')

df.shape, ocid.shape, basic.shape, stat_df.shape
# Out:
# ((600, 4), (562, 4), (560, 5), (562, 10), (560, 11))

# %%
ocid.columns
# Out:
# Index(['character_name', 'server_name', 'job', 'ocid'], dtype='object')

# %%
basic.columns
# Out:
# Index(['character_name', 'character_date_create', 'character_create_type_name',
#        'character_class_name', 'character_nation_name', 'character_gender',
#        'character_exp', 'character_level', 'server_name', 'job'],
#       dtype='object')

# %%
stat_df.columns
# Out:
# Index(['ocid', 'character_name', 'server_name', 'job', '힘', '지력', '지혜', '건강',
#        '민첩', '체력치', '마력치'],
#       dtype='object')

# %%
ocid
# Out:
#     character_name server_name job  \
# 0               포맨           연  전사
# 1           신이내린한분           연  전사
# 2             바리스타           연  전사
# 3              호불팔           연  전사
# 4               조루           연  전사
# ..             ...         ...  ..
# 557             명쾌           진  살수
# 558            포비츠           진  살수
# 559             자체           진  살수
# 560             수고           진  살수
# 561             디귿           진  살수
#
#                                                   ocid
# 0                     d3c2bda905bda4fcdbf9a3b30972a233
# 1    6b7a4d4d779c8d55ea92ec4ae0ac14f5efe8d04e6d233b...
# 2    17c7a3a794cceab47d6d4c869a8f7522efe8d04e6d233b...
# 3    a198e09876905fad8e6a91c18797ced186e68d4012202d...
# 4    c1ad15f3ed217b17980cb516231bbdfe46a65b8b6b5e84...
# ..                                                 ...
# 557                   4ddb4992155bf1f714c82e521118452b
# 558                   affadd68e4702940330fc4a12066c984
# ...

# %%
basic
# Out:
#     character_name     character_date_create character_create_type_name  \
# 0               포맨   2015-10-18T02:20:37.25Z                     캐릭터_일반
# 1           신이내린한분      2008-09-03T10:04:19Z                     캐릭터_일반
# 2             바리스타      2016-01-17T00:50:13Z                     캐릭터_일반
# 3              호불팔      2017-04-10T13:14:06Z                     캐릭터_일반
# 4               조루   2022-12-21T14:05:28.25Z                     캐릭터_일반
# ..             ...                       ...                        ...
# 557             명쾌  2025-05-02T06:48:39.125Z                     캐릭터_일반
# 558            포비츠    2025-02-08T13:18:43.5Z                     캐릭터_일반
# 559             자체  2023-12-25T15:19:50.375Z                     캐릭터_일반
# 560             수고                       NaN                     캐릭터_일반
# 561             디귿      2024-01-09T17:10:27Z                     캐릭터_일반
#
#     character_class_name character_nation_name character_gender  \
# ...

# %%
stat
# Out:
#                                                   stat  \
# 0    [{'stat_name': '힘', 'stat_value': '1348'}, {'s...
# 1    [{'stat_name': '힘', 'stat_value': '1228'}, {'s...
# 2    [{'stat_name': '힘', 'stat_value': '1034'}, {'s...
# 3    [{'stat_name': '힘', 'stat_value': '1360'}, {'s...
# 4    [{'stat_name': '힘', 'stat_value': '1308'}, {'s...
# ..                                                 ...
# 555  [{'stat_name': '힘', 'stat_value': '1085'}, {'s...
# 556  [{'stat_name': '힘', 'stat_value': '877'}, {'st...
# 557  [{'stat_name': '힘', 'stat_value': '883'}, {'st...
# 558  [{'stat_name': '힘', 'stat_value': '890'}, {'st...
# 559  [{'stat_name': '힘', 'stat_value': '867'}, {'st...
#
#                                                   ocid character_name  \
# 0                     d3c2bda905bda4fcdbf9a3b30972a233             포맨
# 1    6b7a4d4d779c8d55ea92ec4ae0ac14f5efe8d04e6d233b...         신이내린한분
# 2    17c7a3a794cceab47d6d4c869a8f7522efe8d04e6d233b...           바리스타
# ...

# %%
merge_df = pd.read_csv('./main_analysis')
# Out:
# Index(['character_name', 'server_name', 'job', 'ocid'], dtype='object')

# %%
basic
# Out:
#     character_name     character_date_create character_create_type_name  \
# 0               포맨   2015-10-18T02:20:37.25Z                     캐릭터_일반
# 1           신이내린한분      2008-09-03T10:04:19Z                     캐릭터_일반
# 2             바리스타      2016-01-17T00:50:13Z                     캐릭터_일반
# 3              호불팔      2017-04-10T13:14:06Z                     캐릭터_일반
# 4               조루   2022-12-21T14:05:28.25Z                     캐릭터_일반
# ..             ...                       ...                        ...
# 557             명쾌  2025-05-02T06:48:39.125Z                     캐릭터_일반
# 558            포비츠    2025-02-08T13:18:43.5Z                     캐릭터_일반
# 559             자체  2023-12-25T15:19:50.375Z                     캐릭터_일반
# 560             수고                       NaN                     캐릭터_일반
# 561             디귿      2024-01-09T17:10:27Z                     캐릭터_일반
#
#     character_class_name character_nation_name character_gender  \
# ...

# %%
basic.columns
# Out:
# Index(['character_name', 'character_date_create', 'character_create_type_name',
#        'character_class_name', 'character_nation_name', 'character_gender',
#        'character_exp', 'character_level', 'server_name', 'job'],
#       dtype='object')

# %%
ocid.head()
# Out:
#     게임아이디 서버  직업  순위
# 0      포맨  연  전사   1
# 1  신이내린한분  연  전사   2
# 2    바리스타  연  전사   3
# 3     호불팔  연  전사   4
# 4      조루  연  전사   5

# %%
df.head()
# Out:
#     게임아이디 서버  직업  순위
# 0      포맨  연  전사   1
# 1  신이내린한분  연  전사   2
# 2    바리스타  연  전사   3
# 3     호불팔  연  전사   4
# 4      조루  연  전사   5

# %%
import pandas as pd

# %%
df = pd.read_csv('./data/baram_ranker.csv')
ocid = pd.read_csv('./data/ocid.csv')
basic = pd.read_csv('./data/basic.csv')
stat = pd.read_csv('./data/stat.csv')


df.shape, ocid.shape, stat.shape, basic.shape
# Out:
# ((600, 4), (562, 4), (560, 5), (562, 10))

# %%
for i in stat['stat']:
    print(i)
# Out:
# [{'stat_name': '힘', 'stat_value': '1348'}, {'stat_name': '지력', 'stat_value': '497'}, {'stat_name': '지혜', 'stat_value': '387'}, {'stat_name': '건강', 'stat_value': '565'}, {'stat_name': '민첩', 'stat_value': '720'}, {'stat_name': '체력치', 'stat_value': '22731261'}, {'stat_name': '마력치', 'stat_value': '4746820'}]
# [{'stat_name': '힘', 'stat_value': '1228'}, {'stat_name': '지력', 'stat_value': '614'}, {'stat_name': '지혜', 'stat_value': '430'}, {'stat_name': '건강', 'stat_value': '523'}, {'stat_name': '민첩', 'stat_value': '709'}, {'stat_name': '체력치', 'stat_value': '21260856'}, {'stat_name': '마력치', 'stat_value': '4957741'}]
# [{'stat_name': '힘', 'stat_value': '1034'}, {'stat_name': '지력', 'stat_value': '365'}, {'stat_name': '지혜', 'stat_value': '334'}, {'stat_name': '건강', 'stat_value': '508'}, {'stat_name': '민첩', 'stat_value': '535'}, {'stat_name': '체력치', 'stat_value': '15987582'}, {'stat_name': '마력치', 'stat_value': '3507709'}]
# ...

# %%
df[df['게임아이디']=='디귿']
# Out:
#     게임아이디 서버  직업  순위
# 599    디귿  진  살수  10

# %%
ocid.head()
# Out:
#     게임아이디 서버  직업  순위
# 0      포맨  연  전사   1
# 1  신이내린한분  연  전사   2
# 2    바리스타  연  전사   3
# 3     호불팔  연  전사   4
# 4      조루  연  전사   5

# %%
df.head()
# Out:
#     게임아이디 서버  직업  순위
# 0      포맨  연  전사   1
# 1  신이내린한분  연  전사   2
# 2    바리스타  연  전사   3
# 3     호불팔  연  전사   4
# 4      조루  연  전사   5

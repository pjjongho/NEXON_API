# %%
import pandas as pd

# %%
df = pd.read_csv('../../collected_data/rank_info.csv')
df.head()
# Out:
#   user_name grade     grade_exp  grade_ranking season_grade  season_grade_exp  \
# 0      연주핑.   대원수  2.110678e+09            1.0         총사령관       350524746.0
# 1        19    원수  1.940826e+09            2.0          사령관       321896461.0
# 2    상추들고튀어    원수  1.818515e+09            3.0         부사령관       165110645.0
# 3        사자    원수  1.744758e+09            4.0         총사령관       343035345.0
# 4        폭력    원수  1.632610e+09            3.0         특급준장        10814347.0
#
#    season_grade_ranking                              ouid
# 0                   7.0  9b2852e25a85deebc5ce4173b1ccc1e6
# 1                  12.0  18e17412f97995c818b669bf4052a753
# 2                 320.0  1dde487186c06c2f54e65484219d1d09
# 3                   8.0  bc0a86cc5d24182a2e09a2d29644e205
# 4               79790.0  5d84519cf2b0e9c3d69ec23a4a859e12

# %%
df = df.drop(['user_name','grade','grade_exp','season_grade','season_grade_exp'], axis=1)

# %%
df.to_csv('../../analysis/final_data/rank_final.csv', index=False, encoding='utf-8-sig')

# %%
import pandas as pd
import os

# %%
os.listdir()
# Out:
# ['get_recent-info.py', 'recent-info_df_eda.ipynb', 'sa_3.txt', '__pycache__']

# %%
df_recent = pd.read_csv('../../collected_data/recent-info.csv')

# %%
# 여기도 마찬가지로 user_name drop

df_recent = df_recent.drop('user_name', axis=1)
df_recent.to_csv('../../collected_data/recent-info_final.csv',index=False, encoding='utf-8-sig')

# %%
df_recent.isna().sum()
# Out:
# recent_win_rate           19
# recent_kill_death_rate    19
# recent_assault_rate       19
# recent_sniper_rate        19
# recent_special_rate       19
# ouid                       0
# dtype: int64

# %%
import pandas as pd
import os

# %%
df_recent = pd.read_csv('../../collected_data/recent-info.csv')

# %%
# 여기도 마찬가지로 user_name drop

# df_recent = df_recent.drop('user_name', axis=1)
# df_recent.to_csv('../../collected_data/recent-info_final.csv',index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv('../../collected_data/recent-info_final.csv')
# Out:
#    recent_win_rate  recent_kill_death_rate  recent_assault_rate  \
# 0        83.333328               56.310677            59.523808
# 1        90.000000               66.500000            71.000000
# 2       100.000000               56.000000            51.333332
# 3        48.333332               49.833332            50.333332
# 4              NaN                     NaN                  NaN
#
#    recent_sniper_rate  recent_special_rate                              ouid
# 0           60.000000            76.470589  9b2852e25a85deebc5ce4173b1ccc1e6
# 1           77.333336            67.666664  18e17412f97995c818b669bf4052a753
# 2           67.333336            55.333332  1dde487186c06c2f54e65484219d1d09
# 3           60.000000            49.333332  bc0a86cc5d24182a2e09a2d29644e205
# 4                 NaN                  NaN  5d84519cf2b0e9c3d69ec23a4a859e12

# %%
df.to_csv('../../analysis/final_data/recent_final.csv', index=False, encoding='utf-8-sig')

# %%
import pandas as pd

# %%
df_match = pd.read_csv('df_match.csv')
df_merged = pd.read_csv('df_merged.csv')
match_result = pd.read_csv('match_results.csv')

# %%
df_match
# Out:
#     team_id  match_result user_name season_grade      guild_name  kill  death  \
# 0         1             2        자다         특급준장        cynosure    10     12
# 1         1             2        도리         특급대장              마뇽     9     13
# 2         0             1      rxvx         특급대장      UlsaN_CIaN    21      8
# 3         1             2         킥         특급대장  lunatic`Gaming    20     13
# 4         1             2        T1         부사령관              활력     9     13
# 5         1             2       도독이         특급대장            도독이들    12     13
# 6         1             2     YAR`'         특급대장             ΗΑΕ     1      1
# 7         0             1       임메리         특급대장              명왕    12     15
# 8         0             1      ㅈㅋㅋㅋ     특공중령 5호봉         ː대구광역시ː     5     12
# 9         0             1   (♡'v'♡)         특급중장           마라탕후룩     6     13
# 10        0             1      ㅇㄴS2         특급대장             NaN    14      9
# ...

# %%
match_result
# Out:
#    user_name  match_result            match_id  team_id
# 0         자다             0  250718062509119001        1
# 1         도리             0  250718062509119001        1
# 2       rxvx             1  250718062509119001        0
# 3          킥             0  250718062509119001        1
# 4         T1             0  250718062509119001        1
# 5        도독이             0  250718062509119001        1
# 6      YAR`'             0  250718062509119001        1
# 7        임메리             1  250718062509119001        0
# 8       ㅈㅋㅋㅋ             1  250718062509119001        0
# 9    (♡'v'♡)             1  250718062509119001        0
# 10      ㅇㄴS2             1  250718062509119001        0
# 11       정재엽             1  250718062509119001        0

# %%
df_merged
# Out:
#   user_name  grade_ranking  season_grade_ranking  recent_win_rate  \
# 0        아리             21                  3110       100.000000
# 1   (♡'v'♡)         232536                 94348        50.000000
# 2        T1           6422                   926        50.000000
# 3      ㅇㄴS2          65518                 46042        85.000000
# 4       도독이          26914                 54316        43.333332
# 5        도리         238564                 66508        41.666664
# 6        자다         612323                167853        53.333336
# 7       정재엽          10953                  5937        58.695648
# 8         킥          21918                 64949        50.000000
#
#    recent_kill_death_rate  recent_assault_rate  recent_sniper_rate  \
# 0               56.833332            51.666664           50.000000
# 1               40.833332            39.000000           50.333332
# 2               53.846157             0.000000           67.346939
# ...
